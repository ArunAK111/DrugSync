# %%
from datetime import datetime
import random

import pandas as pd
import numpy as np
import torch
from torch import nn 
from torch import optim
from torch.utils.data import DataLoader
from sklearn import metrics

import layers
import models
import custom_loss
import time

# %%
from data_preprocessing import DrugDataset, DrugDataLoader, TOTAL_ATOM_FEATS

# %%
TOTAL_ATOM_FEATS
# Out:
# 55

# %%
df_ddi_train = pd.read_csv('data/ddi_training.csv')
df_ddi_val = pd.read_csv('data/ddi_validation.csv')
df_ddi_test = pd.read_csv('data/ddi_test.csv')

# %%
train_tup = [(h, t, r) for h, t, r in zip(df_ddi_train['d1'], df_ddi_train['d2'], df_ddi_train['type'])]
val_tup = [(h, t, r) for h, t, r in zip(df_ddi_val['d1'], df_ddi_val['d2'], df_ddi_val['type'])]
test_tup = [(h, t, r) for h, t, r in zip(df_ddi_test['d1'], df_ddi_test['d2'], df_ddi_test['type'])]

# %%
len(train_tup)
# Out:
# 115185

# %%
len(val_tup)
# Out:
# 38348

# %%
len(test_tup)
# Out:
# 38337

# %%
total = len(val_tup) + len(train_tup) + len(test_tup)
len(train_tup) / total, len(test_tup)/total, len(val_tup)/total
# Out:
# (0.6003283473184969, 0.19980716109866056, 0.19986449158284256)

# %%
# Hyperparameters
n_atom_feats = TOTAL_ATOM_FEATS
n_atom_hid = 64
rel_total = 86
lr = 1e-2
weight_decay = 5e-4
n_epochs = 300
neg_samples = 1
batch_size = 1024
data_size_ratio = 1
kge_dim = 64

# %%
train_data = DrugDataset(train_tup, ratio=data_size_ratio, neg_ent=neg_samples)

# %%
val_data = DrugDataset(val_tup, ratio=data_size_ratio, disjoint_split=False)
test_data = DrugDataset(test_tup, disjoint_split=False)

# %%
print(f"Training with {len(train_data)} samples, validating with {len(val_data)}, and testing with {len(test_data)}")
# Out:
# Training with 115185 samples, validating with 38348, and testing with 38337

# %%
train_data_loader = DrugDataLoader(train_data, batch_size=batch_size, shuffle=True)
val_data_loader = DrugDataLoader(val_data, batch_size=batch_size *3)
test_data_loader = DrugDataLoader(test_data, batch_size=batch_size *3)

# %%
def do_compute(batch, device, training=True):
        '''
            *batch: (pos_tri, neg_tri)
            *pos/neg_tri: (batch_h, batch_t, batch_r)
        '''
        probas_pred, ground_truth = [], []
        pos_tri, neg_tri = batch
        
        pos_tri = [tensor.to(device=device) for tensor in pos_tri]
        p_score = model(pos_tri)
        probas_pred.append(torch.sigmoid(p_score.detach()).cpu())
        ground_truth.append(np.ones(len(p_score)))

        neg_tri = [tensor.to(device=device) for tensor in neg_tri]
        n_score = model(neg_tri)
        probas_pred.append(torch.sigmoid(n_score.detach()).cpu())
        ground_truth.append(np.zeros(len(n_score)))

        probas_pred = np.concatenate(probas_pred)
        ground_truth = np.concatenate(ground_truth)

        return p_score, n_score, probas_pred, ground_truth

# %%
def do_compute_metrics(probas_pred, target):

    pred = (probas_pred >= 0.5).astype(int)

    acc = metrics.accuracy_score(target, pred)
    auc_roc = metrics.roc_auc_score(target, probas_pred)
    f1_score = metrics.f1_score(target, pred)

    p, r, t = metrics.precision_recall_curve(target, probas_pred)
    auc_prc = metrics.auc(r, p)

    return acc, auc_roc, auc_prc

# %%
def train(model, train_data_loader, val_data_loader, loss_fn,  optimizer, n_epochs, device, scheduler=None):
    print('Starting training at', datetime.today())
    for i in range(1, n_epochs+1):
        start = time.time()
        train_loss = 0
        train_loss_pos = 0
        train_loss_neg = 0
        val_loss = 0
        val_loss_pos = 0
        val_loss_neg = 0
        train_probas_pred = []
        train_ground_truth = []
        val_probas_pred = []
        val_ground_truth = []

        for batch in train_data_loader:
            model.train()
            p_score, n_score, probas_pred, ground_truth = do_compute(batch, device)
            train_probas_pred.append(probas_pred)
            train_ground_truth.append(ground_truth)
            loss, loss_p, loss_n = loss_fn(p_score, n_score)
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * len(p_score)
        train_loss /= len(train_data)

        with torch.no_grad():
            train_probas_pred = np.concatenate(train_probas_pred)
            train_ground_truth = np.concatenate(train_ground_truth)

            train_acc, train_auc_roc, train_auc_prc = do_compute_metrics(train_probas_pred, train_ground_truth)

            for batch in val_data_loader:
                model.eval()
                p_score, n_score, probas_pred, ground_truth = do_compute(batch, device)
                val_probas_pred.append(probas_pred)
                val_ground_truth.append(ground_truth)
                loss, loss_p, loss_n = loss_fn(p_score, n_score)
                val_loss += loss.item() * len(p_score)            

            val_loss /= len(val_data)
            val_probas_pred = np.concatenate(val_probas_pred)
            val_ground_truth = np.concatenate(val_ground_truth)
            val_acc, val_auc_roc, val_auc_prc = do_compute_metrics(val_probas_pred, val_ground_truth)
               
        if scheduler:
            print('scheduling')
            scheduler.step()


        print(f'Epoch: {i} ({time.time() - start:.4f}s), train_loss: {train_loss:.4f}, val_loss: {val_loss:.4f},'
        f' train_acc: {train_acc:.4f}, val_acc:{val_acc:.4f}')
        print(f'\t\ttrain_roc: {train_auc_roc:.4f}, val_roc: {val_auc_roc:.4f}, train_auprc: {train_auc_prc:.4f}, val_auprc: {val_auc_prc:.4f}')

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = models.SSI_DDI(n_atom_feats, n_atom_hid, kge_dim, rel_total, heads_out_feat_params=[32, 32, 32, 32], blocks_params=[2, 2, 2, 2])
loss = custom_loss.SigmoidLoss()
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda epoch: 0.96 ** (epoch))
model
# Out:
# SSI_DDI(
#   (initial_norm): LayerNorm(55, affine=True, mode=graph)
#   (net_norms): ModuleList(
#     (0-3): 4 x LayerNorm(64, affine=True, mode=graph)
#   )
#   (block0): SSI_DDI_Block(
#     (conv): GATConv(55, 32, heads=2)
#     (readout): SAGPooling(GraphConv, 64, min_score=-1, multiplier=1.0)
#   )
#   (block1): SSI_DDI_Block(
#     (conv): GATConv(64, 32, heads=2)
#     (readout): SAGPooling(GraphConv, 64, min_score=-1, multiplier=1.0)
#   )
#   (block2): SSI_DDI_Block(
#     (conv): GATConv(64, 32, heads=2)
#     (readout): SAGPooling(GraphConv, 64, min_score=-1, multiplier=1.0)
#   )
#   (block3): SSI_DDI_Block(
#     (conv): GATConv(64, 32, heads=2)
#     (readout): SAGPooling(GraphConv, 64, min_score=-1, multiplier=1.0)
#   )
#   (co_attention): CoAttentionLayer()
#   (KGE): RESCAL(86, torch.Size([86, 4096]))
# )

# %%
model.to(device=device)
# Out:
# SSI_DDI(
#   (initial_norm): LayerNorm(55, affine=True, mode=graph)
#   (net_norms): ModuleList(
#     (0-3): 4 x LayerNorm(64, affine=True, mode=graph)
#   )
#   (block0): SSI_DDI_Block(
#     (conv): GATConv(55, 32, heads=2)
#     (readout): SAGPooling(GraphConv, 64, min_score=-1, multiplier=1.0)
#   )
#   (block1): SSI_DDI_Block(
#     (conv): GATConv(64, 32, heads=2)
#     (readout): SAGPooling(GraphConv, 64, min_score=-1, multiplier=1.0)
#   )
#   (block2): SSI_DDI_Block(
#     (conv): GATConv(64, 32, heads=2)
#     (readout): SAGPooling(GraphConv, 64, min_score=-1, multiplier=1.0)
#   )
#   (block3): SSI_DDI_Block(
#     (conv): GATConv(64, 32, heads=2)
#     (readout): SAGPooling(GraphConv, 64, min_score=-1, multiplier=1.0)
#   )
#   (co_attention): CoAttentionLayer()
#   (KGE): RESCAL(86, torch.Size([86, 4096]))
# )

# %%
train(model, train_data_loader, val_data_loader, loss, optimizer, n_epochs, device, scheduler)
# Out:
# Starting training at 2024-04-14 03:12:45.520705
# scheduling
# Epoch: 1 (97.9469s), train_loss: 0.6387, val_loss: 0.5915, train_acc: 0.6187, val_acc:0.6779
# 		train_roc: 0.6745, val_roc: 0.7460, train_auprc: 0.6624, val_auprc: 0.7262
# scheduling
# Epoch: 2 (90.6976s), train_loss: 0.5717, val_loss: 0.5532, train_acc: 0.6960, val_acc:0.7126
# 		train_roc: 0.7674, val_roc: 0.7876, train_auprc: 0.7471, val_auprc: 0.7694
# scheduling
# Epoch: 3 (88.1447s), train_loss: 0.5423, val_loss: 0.5373, train_acc: 0.7198, val_acc:0.7271
# 		train_roc: 0.7958, val_roc: 0.8030, train_auprc: 0.7769, val_auprc: 0.7821
# scheduling
# Epoch: 4 (89.3602s), train_loss: 0.5285, val_loss: 0.5230, train_acc: 0.7309, val_acc:0.7359
# 		train_roc: 0.8084, val_roc: 0.8129, train_auprc: 0.7881, val_auprc: 0.7946
# scheduling
# Epoch: 5 (93.8602s), train_loss: 0.5163, val_loss: 0.5098, train_acc: 0.7408, val_acc:0.7472
# 		train_roc: 0.8187, val_roc: 0.8245, train_auprc: 0.7983, val_auprc: 0.8043
# scheduling
# Epoch: 6 (89.7597s), train_loss: 0.5061, val_loss: 0.4974, train_acc: 0.7479, val_acc:0.7557
# 		train_roc: 0.8262, val_roc: 0.8341, train_auprc: 0.8070, val_auprc: 0.8170
# scheduling
# Epoch: 7 (88.8197s), train_loss: 0.4946, val_loss: 0.4925, train_acc: 0.7569, val_acc:0.7592
# 		train_roc: 0.8355, val_roc: 0.8389, train_auprc: 0.8155, val_auprc: 0.8179
# scheduling
# Epoch: 8 (90.4370s), train_loss: 0.4868, val_loss: 0.4903, train_acc: 0.7625, val_acc:0.7607
# 		train_roc: 0.8415, val_roc: 0.8387, train_auprc: 0.8215, val_auprc: 0.8182
# scheduling
# Epoch: 9 (88.7629s), train_loss: 0.4784, val_loss: 0.4729, train_acc: 0.7689, val_acc:0.7751
# 		train_roc: 0.8477, val_roc: 0.8529, train_auprc: 0.8279, val_auprc: 0.8345
# scheduling
# Epoch: 10 (90.0709s), train_loss: 0.4700, val_loss: 0.4696, train_acc: 0.7757, val_acc:0.7771
# 		train_roc: 0.8540, val_roc: 0.8557, train_auprc: 0.8342, val_auprc: 0.8343
# scheduling
# Epoch: 11 (88.9217s), train_loss: 0.4644, val_loss: 0.4657, train_acc: 0.7791, val_acc:0.7792
# 		train_roc: 0.8579, val_roc: 0.8567, train_auprc: 0.8374, val_auprc: 0.8350
# scheduling
# Epoch: 12 (88.2817s), train_loss: 0.4567, val_loss: 0.4565, train_acc: 0.7846, val_acc:0.7860
# 		train_roc: 0.8631, val_roc: 0.8635, train_auprc: 0.8434, val_auprc: 0.8433
# scheduling
# Epoch: 13 (89.2453s), train_loss: 0.4547, val_loss: 0.4591, train_acc: 0.7861, val_acc:0.7829
# 		train_roc: 0.8645, val_roc: 0.8616, train_auprc: 0.8438, val_auprc: 0.8432
# scheduling
# Epoch: 14 (90.7855s), train_loss: 0.4468, val_loss: 0.4484, train_acc: 0.7920, val_acc:0.7925
# 		train_roc: 0.8695, val_roc: 0.8695, train_auprc: 0.8502, val_auprc: 0.8494
# scheduling
# Epoch: 15 (88.7275s), train_loss: 0.4425, val_loss: 0.4426, train_acc: 0.7951, val_acc:0.7937
# 		train_roc: 0.8724, val_roc: 0.8724, train_auprc: 0.8521, val_auprc: 0.8535
# scheduling
# Epoch: 16 (89.4294s), train_loss: 0.4360, val_loss: 0.4469, train_acc: 0.7982, val_acc:0.7945
# 		train_roc: 0.8764, val_roc: 0.8722, train_auprc: 0.8569, val_auprc: 0.8525
# scheduling
# Epoch: 17 (90.6713s), train_loss: 0.4323, val_loss: 0.4399, train_acc: 0.8007, val_acc:0.7941
# 		train_roc: 0.8784, val_roc: 0.8743, train_auprc: 0.8586, val_auprc: 0.8546
# scheduling
# Epoch: 18 (89.4889s), train_loss: 0.4276, val_loss: 0.4297, train_acc: 0.8036, val_acc:0.8030
# 		train_roc: 0.8814, val_roc: 0.8808, train_auprc: 0.8623, val_auprc: 0.8621
# scheduling
# Epoch: 19 (89.2793s), train_loss: 0.4229, val_loss: 0.4266, train_acc: 0.8066, val_acc:0.8049
# 		train_roc: 0.8839, val_roc: 0.8824, train_auprc: 0.8648, val_auprc: 0.8643
# scheduling
# Epoch: 20 (90.4661s), train_loss: 0.4199, val_loss: 0.4219, train_acc: 0.8083, val_acc:0.8070
# 		train_roc: 0.8858, val_roc: 0.8849, train_auprc: 0.8664, val_auprc: 0.8675
# scheduling
# Epoch: 21 (90.2858s), train_loss: 0.4172, val_loss: 0.4177, train_acc: 0.8109, val_acc:0.8098
# 		train_roc: 0.8874, val_roc: 0.8876, train_auprc: 0.8678, val_auprc: 0.8700
# scheduling
# Epoch: 22 (90.3378s), train_loss: 0.4137, val_loss: 0.4194, train_acc: 0.8128, val_acc:0.8098
# 		train_roc: 0.8892, val_roc: 0.8868, train_auprc: 0.8696, val_auprc: 0.8680
# scheduling
# Epoch: 23 (90.6714s), train_loss: 0.4094, val_loss: 0.4131, train_acc: 0.8150, val_acc:0.8120
# 		train_roc: 0.8918, val_roc: 0.8898, train_auprc: 0.8728, val_auprc: 0.8719
# scheduling
# Epoch: 24 (93.4560s), train_loss: 0.4046, val_loss: 0.4114, train_acc: 0.8179, val_acc:0.8130
# 		train_roc: 0.8942, val_roc: 0.8911, train_auprc: 0.8757, val_auprc: 0.8720
# scheduling
# Epoch: 25 (91.6949s), train_loss: 0.4011, val_loss: 0.4105, train_acc: 0.8203, val_acc:0.8155
# 		train_roc: 0.8963, val_roc: 0.8918, train_auprc: 0.8774, val_auprc: 0.8757
# scheduling
# Epoch: 26 (92.3600s), train_loss: 0.3993, val_loss: 0.4070, train_acc: 0.8213, val_acc:0.8162
# 		train_roc: 0.8973, val_roc: 0.8941, train_auprc: 0.8780, val_auprc: 0.8762
# scheduling
# Epoch: 27 (91.2690s), train_loss: 0.3960, val_loss: 0.4008, train_acc: 0.8233, val_acc:0.8217
# 		train_roc: 0.8990, val_roc: 0.8974, train_auprc: 0.8801, val_auprc: 0.8794
# scheduling
# Epoch: 28 (90.5476s), train_loss: 0.3945, val_loss: 0.4047, train_acc: 0.8238, val_acc:0.8176
# 		train_roc: 0.8998, val_roc: 0.8948, train_auprc: 0.8816, val_auprc: 0.8780
# scheduling
# Epoch: 29 (89.4757s), train_loss: 0.3893, val_loss: 0.3989, train_acc: 0.8278, val_acc:0.8230
# 		train_roc: 0.9026, val_roc: 0.8985, train_auprc: 0.8843, val_auprc: 0.8800
# scheduling
# Epoch: 30 (92.0258s), train_loss: 0.3867, val_loss: 0.3998, train_acc: 0.8284, val_acc:0.8187
# 		train_roc: 0.9036, val_roc: 0.8977, train_auprc: 0.8856, val_auprc: 0.8808
# scheduling
# Epoch: 31 (89.6628s), train_loss: 0.3843, val_loss: 0.3992, train_acc: 0.8304, val_acc:0.8179
# 		train_roc: 0.9048, val_roc: 0.9002, train_auprc: 0.8867, val_auprc: 0.8834
# scheduling
# Epoch: 32 (94.1395s), train_loss: 0.3831, val_loss: 0.3913, train_acc: 0.8313, val_acc:0.8285
# 		train_roc: 0.9056, val_roc: 0.9016, train_auprc: 0.8875, val_auprc: 0.8828
# scheduling
# Epoch: 33 (91.7527s), train_loss: 0.3787, val_loss: 0.3876, train_acc: 0.8334, val_acc:0.8299
# 		train_roc: 0.9077, val_roc: 0.9035, train_auprc: 0.8900, val_auprc: 0.8855
# scheduling
# Epoch: 34 (89.8234s), train_loss: 0.3736, val_loss: 0.3832, train_acc: 0.8373, val_acc:0.8324
# 		train_roc: 0.9105, val_roc: 0.9057, train_auprc: 0.8924, val_auprc: 0.8889
# scheduling
# Epoch: 35 (93.5581s), train_loss: 0.3729, val_loss: 0.3823, train_acc: 0.8366, val_acc:0.8331
# 		train_roc: 0.9103, val_roc: 0.9070, train_auprc: 0.8932, val_auprc: 0.8908
# scheduling
# Epoch: 36 (91.5455s), train_loss: 0.3705, val_loss: 0.3794, train_acc: 0.8390, val_acc:0.8347
# 		train_roc: 0.9117, val_roc: 0.9089, train_auprc: 0.8939, val_auprc: 0.8927
# scheduling
# Epoch: 37 (91.4666s), train_loss: 0.3664, val_loss: 0.3817, train_acc: 0.8411, val_acc:0.8320
# 		train_roc: 0.9139, val_roc: 0.9066, train_auprc: 0.8965, val_auprc: 0.8899
# scheduling
# Epoch: 38 (91.7169s), train_loss: 0.3657, val_loss: 0.3784, train_acc: 0.8412, val_acc:0.8367
# 		train_roc: 0.9137, val_roc: 0.9088, train_auprc: 0.8961, val_auprc: 0.8918
# scheduling
# Epoch: 39 (92.0204s), train_loss: 0.3637, val_loss: 0.3747, train_acc: 0.8422, val_acc:0.8358
# 		train_roc: 0.9150, val_roc: 0.9106, train_auprc: 0.8979, val_auprc: 0.8943
# scheduling
# Epoch: 40 (92.4044s), train_loss: 0.3615, val_loss: 0.3697, train_acc: 0.8440, val_acc:0.8405
# 		train_roc: 0.9161, val_roc: 0.9128, train_auprc: 0.8988, val_auprc: 0.8969
# scheduling
# Epoch: 41 (91.6578s), train_loss: 0.3589, val_loss: 0.3719, train_acc: 0.8457, val_acc:0.8389
# 		train_roc: 0.9173, val_roc: 0.9122, train_auprc: 0.9004, val_auprc: 0.8958
# scheduling
# Epoch: 42 (91.6338s), train_loss: 0.3552, val_loss: 0.3705, train_acc: 0.8477, val_acc:0.8379
# 		train_roc: 0.9189, val_roc: 0.9126, train_auprc: 0.9017, val_auprc: 0.8969
# scheduling
# Epoch: 43 (91.8403s), train_loss: 0.3543, val_loss: 0.3692, train_acc: 0.8481, val_acc:0.8395
# 		train_roc: 0.9195, val_roc: 0.9135, train_auprc: 0.9025, val_auprc: 0.8975
# scheduling
# Epoch: 44 (93.0786s), train_loss: 0.3522, val_loss: 0.3654, train_acc: 0.8487, val_acc:0.8430
# 		train_roc: 0.9201, val_roc: 0.9148, train_auprc: 0.9032, val_auprc: 0.8986
# scheduling
# Epoch: 45 (92.0916s), train_loss: 0.3515, val_loss: 0.3629, train_acc: 0.8494, val_acc:0.8422
# 		train_roc: 0.9208, val_roc: 0.9165, train_auprc: 0.9038, val_auprc: 0.9021
# scheduling
# Epoch: 46 (91.5165s), train_loss: 0.3447, val_loss: 0.3626, train_acc: 0.8528, val_acc:0.8442
# 		train_roc: 0.9236, val_roc: 0.9160, train_auprc: 0.9077, val_auprc: 0.8993
# scheduling
# Epoch: 47 (91.0453s), train_loss: 0.3478, val_loss: 0.3621, train_acc: 0.8511, val_acc:0.8451
# 		train_roc: 0.9219, val_roc: 0.9164, train_auprc: 0.9053, val_auprc: 0.9004
# scheduling
# Epoch: 48 (92.4988s), train_loss: 0.3441, val_loss: 0.3563, train_acc: 0.8549, val_acc:0.8477
# 		train_roc: 0.9238, val_roc: 0.9194, train_auprc: 0.9068, val_auprc: 0.9046
# scheduling
# Epoch: 49 (92.1123s), train_loss: 0.3422, val_loss: 0.3646, train_acc: 0.8548, val_acc:0.8418
# 		train_roc: 0.9246, val_roc: 0.9153, train_auprc: 0.9083, val_auprc: 0.8996
# scheduling
# Epoch: 50 (91.0268s), train_loss: 0.3398, val_loss: 0.3564, train_acc: 0.8560, val_acc:0.8482
# 		train_roc: 0.9256, val_roc: 0.9190, train_auprc: 0.9092, val_auprc: 0.9044
# scheduling
# Epoch: 51 (91.4484s), train_loss: 0.3379, val_loss: 0.3533, train_acc: 0.8574, val_acc:0.8491
# 		train_roc: 0.9267, val_roc: 0.9204, train_auprc: 0.9111, val_auprc: 0.9047
# scheduling
# Epoch: 52 (91.9225s), train_loss: 0.3355, val_loss: 0.3590, train_acc: 0.8588, val_acc:0.8446
# 		train_roc: 0.9278, val_roc: 0.9188, train_auprc: 0.9116, val_auprc: 0.9037
# scheduling
# Epoch: 53 (91.5887s), train_loss: 0.3359, val_loss: 0.3540, train_acc: 0.8585, val_acc:0.8467
# 		train_roc: 0.9273, val_roc: 0.9198, train_auprc: 0.9112, val_auprc: 0.9052
# scheduling
# Epoch: 54 (92.1699s), train_loss: 0.3316, val_loss: 0.3497, train_acc: 0.8614, val_acc:0.8510
# 		train_roc: 0.9291, val_roc: 0.9225, train_auprc: 0.9133, val_auprc: 0.9084
# scheduling
# Epoch: 55 (90.8937s), train_loss: 0.3306, val_loss: 0.3481, train_acc: 0.8613, val_acc:0.8515
# 		train_roc: 0.9294, val_roc: 0.9229, train_auprc: 0.9138, val_auprc: 0.9092
# scheduling
# Epoch: 56 (91.3287s), train_loss: 0.3289, val_loss: 0.3467, train_acc: 0.8618, val_acc:0.8525
# 		train_roc: 0.9301, val_roc: 0.9235, train_auprc: 0.9146, val_auprc: 0.9090
# scheduling
# Epoch: 57 (91.9820s), train_loss: 0.3278, val_loss: 0.3484, train_acc: 0.8627, val_acc:0.8507
# 		train_roc: 0.9310, val_roc: 0.9228, train_auprc: 0.9152, val_auprc: 0.9083
# scheduling
# Epoch: 58 (92.0413s), train_loss: 0.3260, val_loss: 0.3465, train_acc: 0.8640, val_acc:0.8530
# 		train_roc: 0.9314, val_roc: 0.9236, train_auprc: 0.9158, val_auprc: 0.9098
# scheduling
# Epoch: 59 (91.0899s), train_loss: 0.3262, val_loss: 0.3443, train_acc: 0.8638, val_acc:0.8540
# 		train_roc: 0.9314, val_roc: 0.9249, train_auprc: 0.9156, val_auprc: 0.9112
# scheduling
# Epoch: 60 (90.9949s), train_loss: 0.3233, val_loss: 0.3477, train_acc: 0.8659, val_acc:0.8503
# 		train_roc: 0.9327, val_roc: 0.9229, train_auprc: 0.9174, val_auprc: 0.9092
# scheduling
# Epoch: 61 (91.4026s), train_loss: 0.3216, val_loss: 0.3393, train_acc: 0.8662, val_acc:0.8555
# 		train_roc: 0.9334, val_roc: 0.9266, train_auprc: 0.9185, val_auprc: 0.9143
# scheduling
# Epoch: 62 (91.6347s), train_loss: 0.3200, val_loss: 0.3431, train_acc: 0.8670, val_acc:0.8548
# 		train_roc: 0.9339, val_roc: 0.9254, train_auprc: 0.9187, val_auprc: 0.9115
# scheduling
# Epoch: 63 (92.2556s), train_loss: 0.3187, val_loss: 0.3425, train_acc: 0.8678, val_acc:0.8542
# 		train_roc: 0.9344, val_roc: 0.9261, train_auprc: 0.9195, val_auprc: 0.9129
# scheduling
# Epoch: 64 (92.3653s), train_loss: 0.3174, val_loss: 0.3399, train_acc: 0.8678, val_acc:0.8559
# 		train_roc: 0.9349, val_roc: 0.9264, train_auprc: 0.9202, val_auprc: 0.9126
# scheduling
# Epoch: 65 (91.6842s), train_loss: 0.3160, val_loss: 0.3423, train_acc: 0.8689, val_acc:0.8564
# 		train_roc: 0.9355, val_roc: 0.9253, train_auprc: 0.9206, val_auprc: 0.9108
# scheduling
# Epoch: 66 (91.7887s), train_loss: 0.3152, val_loss: 0.3388, train_acc: 0.8695, val_acc:0.8583
# 		train_roc: 0.9359, val_roc: 0.9270, train_auprc: 0.9216, val_auprc: 0.9137
# scheduling
# Epoch: 67 (90.9503s), train_loss: 0.3134, val_loss: 0.3384, train_acc: 0.8707, val_acc:0.8575
# 		train_roc: 0.9365, val_roc: 0.9269, train_auprc: 0.9223, val_auprc: 0.9137
# scheduling
# Epoch: 68 (91.6566s), train_loss: 0.3105, val_loss: 0.3352, train_acc: 0.8710, val_acc:0.8585
# 		train_roc: 0.9376, val_roc: 0.9288, train_auprc: 0.9240, val_auprc: 0.9159
# scheduling
# Epoch: 69 (99.2473s), train_loss: 0.3108, val_loss: 0.3379, train_acc: 0.8719, val_acc:0.8580
# 		train_roc: 0.9374, val_roc: 0.9277, train_auprc: 0.9229, val_auprc: 0.9142
# scheduling
# Epoch: 70 (91.5907s), train_loss: 0.3094, val_loss: 0.3348, train_acc: 0.8715, val_acc:0.8595
# 		train_roc: 0.9382, val_roc: 0.9293, train_auprc: 0.9245, val_auprc: 0.9163
# scheduling
# Epoch: 71 (91.0336s), train_loss: 0.3082, val_loss: 0.3368, train_acc: 0.8737, val_acc:0.8576
# 		train_roc: 0.9385, val_roc: 0.9284, train_auprc: 0.9238, val_auprc: 0.9147
# scheduling
# Epoch: 72 (92.1864s), train_loss: 0.3078, val_loss: 0.3344, train_acc: 0.8737, val_acc:0.8598
# 		train_roc: 0.9387, val_roc: 0.9290, train_auprc: 0.9244, val_auprc: 0.9161
# scheduling
# Epoch: 73 (91.6015s), train_loss: 0.3061, val_loss: 0.3297, train_acc: 0.8741, val_acc:0.8629
# 		train_roc: 0.9394, val_roc: 0.9311, train_auprc: 0.9252, val_auprc: 0.9178
# scheduling
# Epoch: 74 (91.9729s), train_loss: 0.3071, val_loss: 0.3312, train_acc: 0.8738, val_acc:0.8624
# 		train_roc: 0.9388, val_roc: 0.9306, train_auprc: 0.9247, val_auprc: 0.9175
# scheduling
# Epoch: 75 (91.4236s), train_loss: 0.3037, val_loss: 0.3323, train_acc: 0.8744, val_acc:0.8606
# 		train_roc: 0.9403, val_roc: 0.9297, train_auprc: 0.9269, val_auprc: 0.9168
# scheduling
# Epoch: 76 (91.9019s), train_loss: 0.3033, val_loss: 0.3276, train_acc: 0.8755, val_acc:0.8629
# 		train_roc: 0.9401, val_roc: 0.9320, train_auprc: 0.9263, val_auprc: 0.9201
# scheduling
# Epoch: 77 (91.6392s), train_loss: 0.3024, val_loss: 0.3290, train_acc: 0.8771, val_acc:0.8625
# 		train_roc: 0.9407, val_roc: 0.9315, train_auprc: 0.9268, val_auprc: 0.9190
# scheduling
# Epoch: 78 (91.1481s), train_loss: 0.3025, val_loss: 0.3325, train_acc: 0.8766, val_acc:0.8623
# 		train_roc: 0.9408, val_roc: 0.9305, train_auprc: 0.9268, val_auprc: 0.9171
# scheduling
# Epoch: 79 (92.7761s), train_loss: 0.2996, val_loss: 0.3356, train_acc: 0.8782, val_acc:0.8586
# 		train_roc: 0.9416, val_roc: 0.9294, train_auprc: 0.9278, val_auprc: 0.9163
# scheduling
# Epoch: 80 (92.0381s), train_loss: 0.2992, val_loss: 0.3269, train_acc: 0.8776, val_acc:0.8646
# 		train_roc: 0.9417, val_roc: 0.9322, train_auprc: 0.9285, val_auprc: 0.9196
# scheduling
# Epoch: 81 (1402.9840s), train_loss: 0.3005, val_loss: 0.3301, train_acc: 0.8773, val_acc:0.8621
# 		train_roc: 0.9413, val_roc: 0.9310, train_auprc: 0.9273, val_auprc: 0.9177
# scheduling
# Epoch: 82 (93.6119s), train_loss: 0.2990, val_loss: 0.3280, train_acc: 0.8783, val_acc:0.8637
# 		train_roc: 0.9419, val_roc: 0.9320, train_auprc: 0.9280, val_auprc: 0.9191
# scheduling
# Epoch: 83 (91.4161s), train_loss: 0.2982, val_loss: 0.3261, train_acc: 0.8794, val_acc:0.8644
# 		train_roc: 0.9423, val_roc: 0.9327, train_auprc: 0.9286, val_auprc: 0.9212
# scheduling
# Epoch: 84 (90.1591s), train_loss: 0.2970, val_loss: 0.3280, train_acc: 0.8789, val_acc:0.8634
# 		train_roc: 0.9427, val_roc: 0.9319, train_auprc: 0.9295, val_auprc: 0.9192
# scheduling
# Epoch: 85 (88.4912s), train_loss: 0.2960, val_loss: 0.3307, train_acc: 0.8793, val_acc:0.8624
# 		train_roc: 0.9431, val_roc: 0.9307, train_auprc: 0.9300, val_auprc: 0.9172
# scheduling
# Epoch: 86 (91.2865s), train_loss: 0.2954, val_loss: 0.3250, train_acc: 0.8802, val_acc:0.8655
# 		train_roc: 0.9434, val_roc: 0.9327, train_auprc: 0.9300, val_auprc: 0.9200
# scheduling
# Epoch: 87 (90.2383s), train_loss: 0.2940, val_loss: 0.3243, train_acc: 0.8811, val_acc:0.8650
# 		train_roc: 0.9438, val_roc: 0.9335, train_auprc: 0.9303, val_auprc: 0.9218
# scheduling
# Epoch: 88 (93.0750s), train_loss: 0.2941, val_loss: 0.3249, train_acc: 0.8802, val_acc:0.8661
# 		train_roc: 0.9437, val_roc: 0.9335, train_auprc: 0.9305, val_auprc: 0.9219
# scheduling
# Epoch: 89 (93.5482s), train_loss: 0.2939, val_loss: 0.3274, train_acc: 0.8805, val_acc:0.8642
# 		train_roc: 0.9439, val_roc: 0.9323, train_auprc: 0.9307, val_auprc: 0.9196
# scheduling
# Epoch: 90 (93.8667s), train_loss: 0.2893, val_loss: 0.3237, train_acc: 0.8827, val_acc:0.8661
# 		train_roc: 0.9457, val_roc: 0.9338, train_auprc: 0.9333, val_auprc: 0.9219
# scheduling
# Epoch: 91 (92.8965s), train_loss: 0.2915, val_loss: 0.3270, train_acc: 0.8821, val_acc:0.8637
# 		train_roc: 0.9446, val_roc: 0.9326, train_auprc: 0.9315, val_auprc: 0.9198
# scheduling
# Epoch: 92 (91.4519s), train_loss: 0.2912, val_loss: 0.3210, train_acc: 0.8821, val_acc:0.8668
# 		train_roc: 0.9448, val_roc: 0.9350, train_auprc: 0.9315, val_auprc: 0.9231
# scheduling
# Epoch: 93 (92.3982s), train_loss: 0.2910, val_loss: 0.3268, train_acc: 0.8827, val_acc:0.8650
# 		train_roc: 0.9450, val_roc: 0.9331, train_auprc: 0.9320, val_auprc: 0.9207
# scheduling
# Epoch: 94 (90.9011s), train_loss: 0.2889, val_loss: 0.3239, train_acc: 0.8829, val_acc:0.8651
# 		train_roc: 0.9457, val_roc: 0.9341, train_auprc: 0.9332, val_auprc: 0.9219
# scheduling
# Epoch: 95 (91.4729s), train_loss: 0.2909, val_loss: 0.3245, train_acc: 0.8828, val_acc:0.8652
# 		train_roc: 0.9448, val_roc: 0.9337, train_auprc: 0.9312, val_auprc: 0.9217
# scheduling
# Epoch: 96 (90.9339s), train_loss: 0.2888, val_loss: 0.3214, train_acc: 0.8835, val_acc:0.8679
# 		train_roc: 0.9458, val_roc: 0.9348, train_auprc: 0.9331, val_auprc: 0.9221
# scheduling
# Epoch: 97 (91.7029s), train_loss: 0.2884, val_loss: 0.3224, train_acc: 0.8836, val_acc:0.8655
# 		train_roc: 0.9458, val_roc: 0.9343, train_auprc: 0.9325, val_auprc: 0.9223
# scheduling
# Epoch: 98 (91.4947s), train_loss: 0.2870, val_loss: 0.3241, train_acc: 0.8848, val_acc:0.8661
# 		train_roc: 0.9464, val_roc: 0.9334, train_auprc: 0.9332, val_auprc: 0.9206
# scheduling
# Epoch: 99 (92.1238s), train_loss: 0.2893, val_loss: 0.3222, train_acc: 0.8835, val_acc:0.8671
# 		train_roc: 0.9454, val_roc: 0.9349, train_auprc: 0.9324, val_auprc: 0.9232
# scheduling
# Epoch: 100 (91.9997s), train_loss: 0.2852, val_loss: 0.3217, train_acc: 0.8853, val_acc:0.8654
# 		train_roc: 0.9471, val_roc: 0.9344, train_auprc: 0.9343, val_auprc: 0.9232
# scheduling
# Epoch: 101 (91.8944s), train_loss: 0.2859, val_loss: 0.3224, train_acc: 0.8847, val_acc:0.8679
# 		train_roc: 0.9468, val_roc: 0.9346, train_auprc: 0.9340, val_auprc: 0.9223
# scheduling
# Epoch: 102 (99.5772s), train_loss: 0.2845, val_loss: 0.3231, train_acc: 0.8859, val_acc:0.8663
# 		train_roc: 0.9474, val_roc: 0.9344, train_auprc: 0.9349, val_auprc: 0.9220
# scheduling
# Epoch: 103 (92.4043s), train_loss: 0.2844, val_loss: 0.3244, train_acc: 0.8859, val_acc:0.8663
# 		train_roc: 0.9474, val_roc: 0.9338, train_auprc: 0.9346, val_auprc: 0.9215
# scheduling
# Epoch: 104 (91.8166s), train_loss: 0.2836, val_loss: 0.3223, train_acc: 0.8857, val_acc:0.8670
# 		train_roc: 0.9476, val_roc: 0.9354, train_auprc: 0.9351, val_auprc: 0.9227
# scheduling
# Epoch: 105 (98.9658s), train_loss: 0.2843, val_loss: 0.3211, train_acc: 0.8856, val_acc:0.8672
# 		train_roc: 0.9473, val_roc: 0.9355, train_auprc: 0.9346, val_auprc: 0.9236
# scheduling
# Epoch: 106 (94.5270s), train_loss: 0.2848, val_loss: 0.3234, train_acc: 0.8854, val_acc:0.8664
# 		train_roc: 0.9471, val_roc: 0.9344, train_auprc: 0.9340, val_auprc: 0.9211
# scheduling
# Epoch: 107 (93.3871s), train_loss: 0.2828, val_loss: 0.3238, train_acc: 0.8869, val_acc:0.8660
# 		train_roc: 0.9478, val_roc: 0.9340, train_auprc: 0.9355, val_auprc: 0.9220
# scheduling
# Epoch: 108 (95.9234s), train_loss: 0.2841, val_loss: 0.3233, train_acc: 0.8853, val_acc:0.8670
# 		train_roc: 0.9472, val_roc: 0.9345, train_auprc: 0.9348, val_auprc: 0.9222
# scheduling
# Epoch: 109 (94.0093s), train_loss: 0.2841, val_loss: 0.3203, train_acc: 0.8855, val_acc:0.8682
# 		train_roc: 0.9474, val_roc: 0.9360, train_auprc: 0.9347, val_auprc: 0.9233
# scheduling
# Epoch: 110 (93.6808s), train_loss: 0.2823, val_loss: 0.3184, train_acc: 0.8867, val_acc:0.8687
# 		train_roc: 0.9481, val_roc: 0.9362, train_auprc: 0.9352, val_auprc: 0.9250
# scheduling
# Epoch: 111 (94.0565s), train_loss: 0.2832, val_loss: 0.3216, train_acc: 0.8861, val_acc:0.8677
# 		train_roc: 0.9477, val_roc: 0.9359, train_auprc: 0.9351, val_auprc: 0.9239
# scheduling
# Epoch: 112 (93.3086s), train_loss: 0.2825, val_loss: 0.3219, train_acc: 0.8867, val_acc:0.8664
# 		train_roc: 0.9477, val_roc: 0.9355, train_auprc: 0.9349, val_auprc: 0.9242
# scheduling
# Epoch: 113 (93.2291s), train_loss: 0.2809, val_loss: 0.3206, train_acc: 0.8880, val_acc:0.8684
# 		train_roc: 0.9485, val_roc: 0.9356, train_auprc: 0.9360, val_auprc: 0.9234
# scheduling
# Epoch: 114 (93.9859s), train_loss: 0.2818, val_loss: 0.3207, train_acc: 0.8873, val_acc:0.8686
# 		train_roc: 0.9480, val_roc: 0.9357, train_auprc: 0.9353, val_auprc: 0.9238
# scheduling
# Epoch: 115 (93.5958s), train_loss: 0.2806, val_loss: 0.3206, train_acc: 0.8878, val_acc:0.8674
# 		train_roc: 0.9486, val_roc: 0.9355, train_auprc: 0.9360, val_auprc: 0.9243
# scheduling
# Epoch: 116 (92.3088s), train_loss: 0.2807, val_loss: 0.3204, train_acc: 0.8875, val_acc:0.8687
# 		train_roc: 0.9485, val_roc: 0.9360, train_auprc: 0.9362, val_auprc: 0.9245
# scheduling
# Epoch: 117 (94.8202s), train_loss: 0.2799, val_loss: 0.3203, train_acc: 0.8877, val_acc:0.8692
# 		train_roc: 0.9488, val_roc: 0.9359, train_auprc: 0.9368, val_auprc: 0.9239
# scheduling
# Epoch: 118 (90.4737s), train_loss: 0.2805, val_loss: 0.3202, train_acc: 0.8868, val_acc:0.8684
# 		train_roc: 0.9487, val_roc: 0.9358, train_auprc: 0.9366, val_auprc: 0.9240
# scheduling
# Epoch: 119 (90.9536s), train_loss: 0.2803, val_loss: 0.3200, train_acc: 0.8883, val_acc:0.8689
# 		train_roc: 0.9485, val_roc: 0.9359, train_auprc: 0.9361, val_auprc: 0.9241
# scheduling
# Epoch: 120 (93.0659s), train_loss: 0.2796, val_loss: 0.3203, train_acc: 0.8880, val_acc:0.8694
# 		train_roc: 0.9491, val_roc: 0.9360, train_auprc: 0.9367, val_auprc: 0.9236
# scheduling
# Epoch: 121 (92.0939s), train_loss: 0.2795, val_loss: 0.3196, train_acc: 0.8881, val_acc:0.8691
# 		train_roc: 0.9489, val_roc: 0.9363, train_auprc: 0.9366, val_auprc: 0.9247
# scheduling
# Epoch: 122 (91.3549s), train_loss: 0.2811, val_loss: 0.3198, train_acc: 0.8872, val_acc:0.8689
# 		train_roc: 0.9483, val_roc: 0.9361, train_auprc: 0.9359, val_auprc: 0.9238
# scheduling
# Epoch: 123 (92.2211s), train_loss: 0.2801, val_loss: 0.3191, train_acc: 0.8879, val_acc:0.8691
# 		train_roc: 0.9487, val_roc: 0.9365, train_auprc: 0.9364, val_auprc: 0.9253
# scheduling
# Epoch: 124 (92.1535s), train_loss: 0.2779, val_loss: 0.3205, train_acc: 0.8898, val_acc:0.8680
# 		train_roc: 0.9497, val_roc: 0.9357, train_auprc: 0.9375, val_auprc: 0.9236
# scheduling
# Epoch: 125 (91.2695s), train_loss: 0.2794, val_loss: 0.3189, train_acc: 0.8883, val_acc:0.8689
# 		train_roc: 0.9490, val_roc: 0.9365, train_auprc: 0.9366, val_auprc: 0.9253
# scheduling
# Epoch: 126 (91.4815s), train_loss: 0.2775, val_loss: 0.3212, train_acc: 0.8893, val_acc:0.8682
# 		train_roc: 0.9497, val_roc: 0.9353, train_auprc: 0.9377, val_auprc: 0.9241
# scheduling
# Epoch: 127 (95.0279s), train_loss: 0.2766, val_loss: 0.3206, train_acc: 0.8894, val_acc:0.8689
# 		train_roc: 0.9503, val_roc: 0.9360, train_auprc: 0.9387, val_auprc: 0.9241
# scheduling
# Epoch: 128 (91.8107s), train_loss: 0.2780, val_loss: 0.3195, train_acc: 0.8885, val_acc:0.8699
# 		train_roc: 0.9496, val_roc: 0.9363, train_auprc: 0.9374, val_auprc: 0.9241
# scheduling
# Epoch: 129 (93.0132s), train_loss: 0.2769, val_loss: 0.3191, train_acc: 0.8898, val_acc:0.8694
# 		train_roc: 0.9500, val_roc: 0.9365, train_auprc: 0.9377, val_auprc: 0.9254
# scheduling
# Epoch: 130 (91.5102s), train_loss: 0.2774, val_loss: 0.3238, train_acc: 0.8892, val_acc:0.8664
# 		train_roc: 0.9497, val_roc: 0.9345, train_auprc: 0.9373, val_auprc: 0.9216
# scheduling
# Epoch: 131 (91.9797s), train_loss: 0.2787, val_loss: 0.3208, train_acc: 0.8891, val_acc:0.8690
# 		train_roc: 0.9492, val_roc: 0.9352, train_auprc: 0.9367, val_auprc: 0.9231
# scheduling
# Epoch: 132 (91.6845s), train_loss: 0.2762, val_loss: 0.3188, train_acc: 0.8902, val_acc:0.8685
# 		train_roc: 0.9503, val_roc: 0.9366, train_auprc: 0.9383, val_auprc: 0.9257
# scheduling
# Epoch: 133 (94.1850s), train_loss: 0.2789, val_loss: 0.3200, train_acc: 0.8887, val_acc:0.8682
# 		train_roc: 0.9491, val_roc: 0.9362, train_auprc: 0.9363, val_auprc: 0.9248
# scheduling
# Epoch: 134 (93.4966s), train_loss: 0.2777, val_loss: 0.3220, train_acc: 0.8891, val_acc:0.8681
# 		train_roc: 0.9496, val_roc: 0.9355, train_auprc: 0.9370, val_auprc: 0.9231
# scheduling
# Epoch: 135 (93.0975s), train_loss: 0.2770, val_loss: 0.3228, train_acc: 0.8891, val_acc:0.8678
# 		train_roc: 0.9499, val_roc: 0.9352, train_auprc: 0.9376, val_auprc: 0.9227
# scheduling
# Epoch: 136 (93.5580s), train_loss: 0.2792, val_loss: 0.3175, train_acc: 0.8881, val_acc:0.8690
# 		train_roc: 0.9490, val_roc: 0.9373, train_auprc: 0.9366, val_auprc: 0.9261
# scheduling
# Epoch: 137 (94.8115s), train_loss: 0.2777, val_loss: 0.3195, train_acc: 0.8890, val_acc:0.8691
# 		train_roc: 0.9495, val_roc: 0.9363, train_auprc: 0.9373, val_auprc: 0.9246
# scheduling
# Epoch: 138 (93.4121s), train_loss: 0.2768, val_loss: 0.3193, train_acc: 0.8890, val_acc:0.8690
# 		train_roc: 0.9500, val_roc: 0.9362, train_auprc: 0.9378, val_auprc: 0.9246
# scheduling
# Epoch: 139 (92.3223s), train_loss: 0.2770, val_loss: 0.3185, train_acc: 0.8893, val_acc:0.8701
# 		train_roc: 0.9499, val_roc: 0.9369, train_auprc: 0.9377, val_auprc: 0.9250
# scheduling
# Epoch: 140 (92.0708s), train_loss: 0.2775, val_loss: 0.3219, train_acc: 0.8895, val_acc:0.8683
# 		train_roc: 0.9495, val_roc: 0.9354, train_auprc: 0.9373, val_auprc: 0.9233
# scheduling
# Epoch: 141 (92.0209s), train_loss: 0.2768, val_loss: 0.3216, train_acc: 0.8896, val_acc:0.8683
# 		train_roc: 0.9500, val_roc: 0.9354, train_auprc: 0.9380, val_auprc: 0.9233
# scheduling
# Epoch: 142 (91.4793s), train_loss: 0.2781, val_loss: 0.3179, train_acc: 0.8892, val_acc:0.8705
# 		train_roc: 0.9493, val_roc: 0.9374, train_auprc: 0.9368, val_auprc: 0.9266
# scheduling
# Epoch: 143 (93.1050s), train_loss: 0.2772, val_loss: 0.3216, train_acc: 0.8891, val_acc:0.8690
# 		train_roc: 0.9496, val_roc: 0.9355, train_auprc: 0.9374, val_auprc: 0.9238
# scheduling
# Epoch: 144 (92.3608s), train_loss: 0.2762, val_loss: 0.3205, train_acc: 0.8898, val_acc:0.8702
# 		train_roc: 0.9503, val_roc: 0.9361, train_auprc: 0.9380, val_auprc: 0.9240
# scheduling
# Epoch: 145 (92.6436s), train_loss: 0.2760, val_loss: 0.3187, train_acc: 0.8900, val_acc:0.8692
# 		train_roc: 0.9503, val_roc: 0.9369, train_auprc: 0.9381, val_auprc: 0.9254
# scheduling
# Epoch: 146 (91.7416s), train_loss: 0.2755, val_loss: 0.3196, train_acc: 0.8898, val_acc:0.8702
# 		train_roc: 0.9505, val_roc: 0.9363, train_auprc: 0.9386, val_auprc: 0.9247
# scheduling
# Epoch: 147 (93.5145s), train_loss: 0.2763, val_loss: 0.3210, train_acc: 0.8897, val_acc:0.8686
# 		train_roc: 0.9501, val_roc: 0.9361, train_auprc: 0.9380, val_auprc: 0.9247
# scheduling
# Epoch: 148 (93.1234s), train_loss: 0.2757, val_loss: 0.3179, train_acc: 0.8897, val_acc:0.8712
# 		train_roc: 0.9503, val_roc: 0.9369, train_auprc: 0.9386, val_auprc: 0.9251
# scheduling
# Epoch: 149 (91.9333s), train_loss: 0.2749, val_loss: 0.3157, train_acc: 0.8902, val_acc:0.8709
# 		train_roc: 0.9505, val_roc: 0.9383, train_auprc: 0.9387, val_auprc: 0.9281
# scheduling
# Epoch: 150 (92.7064s), train_loss: 0.2771, val_loss: 0.3172, train_acc: 0.8890, val_acc:0.8709
# 		train_roc: 0.9497, val_roc: 0.9375, train_auprc: 0.9377, val_auprc: 0.9260
# scheduling
# Epoch: 151 (92.3840s), train_loss: 0.2760, val_loss: 0.3198, train_acc: 0.8900, val_acc:0.8693
# 		train_roc: 0.9502, val_roc: 0.9363, train_auprc: 0.9382, val_auprc: 0.9248
# scheduling
# Epoch: 152 (92.2435s), train_loss: 0.2753, val_loss: 0.3192, train_acc: 0.8903, val_acc:0.8695
# 		train_roc: 0.9505, val_roc: 0.9366, train_auprc: 0.9385, val_auprc: 0.9254
# scheduling
# Epoch: 153 (93.0189s), train_loss: 0.2760, val_loss: 0.3191, train_acc: 0.8895, val_acc:0.8694
# 		train_roc: 0.9502, val_roc: 0.9367, train_auprc: 0.9385, val_auprc: 0.9252
# scheduling
# Epoch: 154 (92.7957s), train_loss: 0.2777, val_loss: 0.3169, train_acc: 0.8890, val_acc:0.8712
# 		train_roc: 0.9494, val_roc: 0.9377, train_auprc: 0.9376, val_auprc: 0.9267
# scheduling
# Epoch: 155 (91.5095s), train_loss: 0.2759, val_loss: 0.3200, train_acc: 0.8897, val_acc:0.8699
# 		train_roc: 0.9504, val_roc: 0.9364, train_auprc: 0.9385, val_auprc: 0.9250
# scheduling
# Epoch: 156 (93.5930s), train_loss: 0.2750, val_loss: 0.3187, train_acc: 0.8908, val_acc:0.8695
# 		train_roc: 0.9506, val_roc: 0.9367, train_auprc: 0.9381, val_auprc: 0.9260
# scheduling
# Epoch: 157 (92.9270s), train_loss: 0.2739, val_loss: 0.3218, train_acc: 0.8905, val_acc:0.8694
# 		train_roc: 0.9510, val_roc: 0.9354, train_auprc: 0.9394, val_auprc: 0.9235
# scheduling
# Epoch: 158 (92.1863s), train_loss: 0.2752, val_loss: 0.3176, train_acc: 0.8898, val_acc:0.8711
# 		train_roc: 0.9507, val_roc: 0.9376, train_auprc: 0.9390, val_auprc: 0.9265
# scheduling
# Epoch: 159 (92.9456s), train_loss: 0.2753, val_loss: 0.3195, train_acc: 0.8903, val_acc:0.8711
# 		train_roc: 0.9504, val_roc: 0.9365, train_auprc: 0.9381, val_auprc: 0.9244
# scheduling
# Epoch: 160 (92.2958s), train_loss: 0.2744, val_loss: 0.3223, train_acc: 0.8912, val_acc:0.8693
# 		train_roc: 0.9506, val_roc: 0.9352, train_auprc: 0.9385, val_auprc: 0.9226
# scheduling
# Epoch: 161 (92.7125s), train_loss: 0.2749, val_loss: 0.3174, train_acc: 0.8904, val_acc:0.8713
# 		train_roc: 0.9507, val_roc: 0.9375, train_auprc: 0.9387, val_auprc: 0.9262
# scheduling
# Epoch: 162 (92.5538s), train_loss: 0.2750, val_loss: 0.3188, train_acc: 0.8907, val_acc:0.8700
# 		train_roc: 0.9506, val_roc: 0.9368, train_auprc: 0.9382, val_auprc: 0.9254
# scheduling
# Epoch: 163 (92.1182s), train_loss: 0.2761, val_loss: 0.3202, train_acc: 0.8896, val_acc:0.8687
# 		train_roc: 0.9502, val_roc: 0.9362, train_auprc: 0.9381, val_auprc: 0.9249
# scheduling
# Epoch: 164 (92.2911s), train_loss: 0.2748, val_loss: 0.3171, train_acc: 0.8905, val_acc:0.8712
# 		train_roc: 0.9508, val_roc: 0.9378, train_auprc: 0.9387, val_auprc: 0.9271
# scheduling
# Epoch: 165 (92.5213s), train_loss: 0.2761, val_loss: 0.3217, train_acc: 0.8898, val_acc:0.8694
# 		train_roc: 0.9502, val_roc: 0.9355, train_auprc: 0.9379, val_auprc: 0.9233
# scheduling
# Epoch: 166 (94.8315s), train_loss: 0.2742, val_loss: 0.3201, train_acc: 0.8913, val_acc:0.8704
# 		train_roc: 0.9509, val_roc: 0.9363, train_auprc: 0.9390, val_auprc: 0.9246
# scheduling
# Epoch: 167 (92.4342s), train_loss: 0.2753, val_loss: 0.3187, train_acc: 0.8906, val_acc:0.8713
# 		train_roc: 0.9504, val_roc: 0.9370, train_auprc: 0.9380, val_auprc: 0.9260
# scheduling
# Epoch: 168 (91.8957s), train_loss: 0.2763, val_loss: 0.3221, train_acc: 0.8896, val_acc:0.8689
# 		train_roc: 0.9502, val_roc: 0.9352, train_auprc: 0.9378, val_auprc: 0.9235
# scheduling
# Epoch: 169 (92.5623s), train_loss: 0.2749, val_loss: 0.3209, train_acc: 0.8902, val_acc:0.8693
# 		train_roc: 0.9507, val_roc: 0.9360, train_auprc: 0.9390, val_auprc: 0.9240
# scheduling
# Epoch: 170 (92.3138s), train_loss: 0.2763, val_loss: 0.3172, train_acc: 0.8902, val_acc:0.8723
# 		train_roc: 0.9499, val_roc: 0.9377, train_auprc: 0.9376, val_auprc: 0.9260
# scheduling
# Epoch: 171 (92.4654s), train_loss: 0.2748, val_loss: 0.3224, train_acc: 0.8903, val_acc:0.8672
# 		train_roc: 0.9506, val_roc: 0.9353, train_auprc: 0.9388, val_auprc: 0.9240
# scheduling
# Epoch: 172 (92.2431s), train_loss: 0.2744, val_loss: 0.3204, train_acc: 0.8906, val_acc:0.8691
# 		train_roc: 0.9507, val_roc: 0.9360, train_auprc: 0.9389, val_auprc: 0.9243
# scheduling
# Epoch: 173 (91.8244s), train_loss: 0.2746, val_loss: 0.3182, train_acc: 0.8906, val_acc:0.8702
# 		train_roc: 0.9506, val_roc: 0.9373, train_auprc: 0.9385, val_auprc: 0.9260
# scheduling
# Epoch: 174 (92.2394s), train_loss: 0.2751, val_loss: 0.3174, train_acc: 0.8905, val_acc:0.8701
# 		train_roc: 0.9504, val_roc: 0.9373, train_auprc: 0.9382, val_auprc: 0.9269
# scheduling
# Epoch: 175 (92.6468s), train_loss: 0.2750, val_loss: 0.3187, train_acc: 0.8899, val_acc:0.8709
# 		train_roc: 0.9506, val_roc: 0.9372, train_auprc: 0.9387, val_auprc: 0.9258
# scheduling
# Epoch: 176 (93.0564s), train_loss: 0.2744, val_loss: 0.3197, train_acc: 0.8903, val_acc:0.8704
# 		train_roc: 0.9509, val_roc: 0.9366, train_auprc: 0.9393, val_auprc: 0.9250
# scheduling
# Epoch: 177 (92.6294s), train_loss: 0.2751, val_loss: 0.3176, train_acc: 0.8900, val_acc:0.8714
# 		train_roc: 0.9505, val_roc: 0.9376, train_auprc: 0.9385, val_auprc: 0.9269
# scheduling
# Epoch: 178 (92.0396s), train_loss: 0.2747, val_loss: 0.3184, train_acc: 0.8905, val_acc:0.8700
# 		train_roc: 0.9507, val_roc: 0.9372, train_auprc: 0.9389, val_auprc: 0.9268
# scheduling
# Epoch: 179 (92.6289s), train_loss: 0.2753, val_loss: 0.3187, train_acc: 0.8902, val_acc:0.8711
# 		train_roc: 0.9505, val_roc: 0.9369, train_auprc: 0.9387, val_auprc: 0.9262
# scheduling
# Epoch: 180 (95.9144s), train_loss: 0.2741, val_loss: 0.3205, train_acc: 0.8908, val_acc:0.8685
# 		train_roc: 0.9509, val_roc: 0.9363, train_auprc: 0.9392, val_auprc: 0.9252
# scheduling
# Epoch: 181 (96.9796s), train_loss: 0.2746, val_loss: 0.3182, train_acc: 0.8907, val_acc:0.8711
# 		train_roc: 0.9507, val_roc: 0.9373, train_auprc: 0.9387, val_auprc: 0.9257
# scheduling
# Epoch: 182 (99.0204s), train_loss: 0.2741, val_loss: 0.3185, train_acc: 0.8909, val_acc:0.8699
# 		train_roc: 0.9510, val_roc: 0.9374, train_auprc: 0.9390, val_auprc: 0.9262
# scheduling
# Epoch: 183 (100.1849s), train_loss: 0.2748, val_loss: 0.3207, train_acc: 0.8903, val_acc:0.8690
# 		train_roc: 0.9507, val_roc: 0.9361, train_auprc: 0.9386, val_auprc: 0.9248
# scheduling
# Epoch: 184 (100.5306s), train_loss: 0.2751, val_loss: 0.3205, train_acc: 0.8905, val_acc:0.8705
# 		train_roc: 0.9503, val_roc: 0.9362, train_auprc: 0.9378, val_auprc: 0.9240
# scheduling
# Epoch: 185 (101.7813s), train_loss: 0.2757, val_loss: 0.3178, train_acc: 0.8901, val_acc:0.8702
# 		train_roc: 0.9503, val_roc: 0.9374, train_auprc: 0.9381, val_auprc: 0.9265
# scheduling
# Epoch: 186 (101.1635s), train_loss: 0.2739, val_loss: 0.3181, train_acc: 0.8905, val_acc:0.8704
# 		train_roc: 0.9511, val_roc: 0.9372, train_auprc: 0.9393, val_auprc: 0.9254
# scheduling
# Epoch: 187 (101.6674s), train_loss: 0.2751, val_loss: 0.3199, train_acc: 0.8903, val_acc:0.8703
# 		train_roc: 0.9505, val_roc: 0.9364, train_auprc: 0.9385, val_auprc: 0.9248
# scheduling
# Epoch: 188 (601.2063s), train_loss: 0.2749, val_loss: 0.3199, train_acc: 0.8906, val_acc:0.8694
# 		train_roc: 0.9506, val_roc: 0.9365, train_auprc: 0.9386, val_auprc: 0.9248
# scheduling
# Epoch: 189 (88.0904s), train_loss: 0.2735, val_loss: 0.3200, train_acc: 0.8905, val_acc:0.8698
# 		train_roc: 0.9512, val_roc: 0.9364, train_auprc: 0.9396, val_auprc: 0.9250
# scheduling
# Epoch: 190 (96.0381s), train_loss: 0.2747, val_loss: 0.3168, train_acc: 0.8905, val_acc:0.8710
# 		train_roc: 0.9507, val_roc: 0.9380, train_auprc: 0.9385, val_auprc: 0.9274
# scheduling
# Epoch: 191 (101.0611s), train_loss: 0.2755, val_loss: 0.3203, train_acc: 0.8893, val_acc:0.8694
# 		train_roc: 0.9505, val_roc: 0.9361, train_auprc: 0.9386, val_auprc: 0.9243
# scheduling
# Epoch: 192 (104.9640s), train_loss: 0.2730, val_loss: 0.3166, train_acc: 0.8917, val_acc:0.8717
# 		train_roc: 0.9513, val_roc: 0.9382, train_auprc: 0.9393, val_auprc: 0.9269
# scheduling
# Epoch: 193 (103.8917s), train_loss: 0.2753, val_loss: 0.3209, train_acc: 0.8904, val_acc:0.8690
# 		train_roc: 0.9504, val_roc: 0.9359, train_auprc: 0.9382, val_auprc: 0.9240
# scheduling
# Epoch: 194 (105.5311s), train_loss: 0.2742, val_loss: 0.3199, train_acc: 0.8913, val_acc:0.8698
# 		train_roc: 0.9509, val_roc: 0.9365, train_auprc: 0.9385, val_auprc: 0.9250
# scheduling
# Epoch: 195 (105.5544s), train_loss: 0.2733, val_loss: 0.3178, train_acc: 0.8906, val_acc:0.8712
# 		train_roc: 0.9513, val_roc: 0.9373, train_auprc: 0.9397, val_auprc: 0.9256
# scheduling
# Epoch: 196 (101.3754s), train_loss: 0.2738, val_loss: 0.3158, train_acc: 0.8914, val_acc:0.8727
# 		train_roc: 0.9512, val_roc: 0.9384, train_auprc: 0.9392, val_auprc: 0.9275
# scheduling
# Epoch: 197 (101.5785s), train_loss: 0.2749, val_loss: 0.3208, train_acc: 0.8897, val_acc:0.8688
# 		train_roc: 0.9507, val_roc: 0.9363, train_auprc: 0.9390, val_auprc: 0.9245
# scheduling
# Epoch: 198 (100.8526s), train_loss: 0.2740, val_loss: 0.3174, train_acc: 0.8908, val_acc:0.8711
# 		train_roc: 0.9510, val_roc: 0.9376, train_auprc: 0.9392, val_auprc: 0.9267
# scheduling
# Epoch: 199 (92.5804s), train_loss: 0.2751, val_loss: 0.3178, train_acc: 0.8908, val_acc:0.8701
# 		train_roc: 0.9506, val_roc: 0.9375, train_auprc: 0.9387, val_auprc: 0.9273
# scheduling
# Epoch: 200 (92.3666s), train_loss: 0.2746, val_loss: 0.3165, train_acc: 0.8907, val_acc:0.8711
# 		train_roc: 0.9507, val_roc: 0.9380, train_auprc: 0.9387, val_auprc: 0.9275
# scheduling
# Epoch: 201 (92.6078s), train_loss: 0.2740, val_loss: 0.3177, train_acc: 0.8912, val_acc:0.8704
# 		train_roc: 0.9509, val_roc: 0.9375, train_auprc: 0.9388, val_auprc: 0.9260
# scheduling
# Epoch: 202 (92.5832s), train_loss: 0.2746, val_loss: 0.3197, train_acc: 0.8906, val_acc:0.8692
# 		train_roc: 0.9506, val_roc: 0.9365, train_auprc: 0.9388, val_auprc: 0.9253
# scheduling
# Epoch: 203 (93.5112s), train_loss: 0.2736, val_loss: 0.3177, train_acc: 0.8911, val_acc:0.8699
# 		train_roc: 0.9511, val_roc: 0.9376, train_auprc: 0.9392, val_auprc: 0.9270
# scheduling
# Epoch: 204 (92.6300s), train_loss: 0.2751, val_loss: 0.3194, train_acc: 0.8908, val_acc:0.8716
# 		train_roc: 0.9505, val_roc: 0.9368, train_auprc: 0.9382, val_auprc: 0.9242
# scheduling
# Epoch: 205 (91.4971s), train_loss: 0.2751, val_loss: 0.3184, train_acc: 0.8908, val_acc:0.8703
# 		train_roc: 0.9504, val_roc: 0.9374, train_auprc: 0.9383, val_auprc: 0.9260
# scheduling
# Epoch: 206 (91.8592s), train_loss: 0.2748, val_loss: 0.3215, train_acc: 0.8906, val_acc:0.8685
# 		train_roc: 0.9506, val_roc: 0.9358, train_auprc: 0.9384, val_auprc: 0.9244
# scheduling
# Epoch: 207 (92.0697s), train_loss: 0.2753, val_loss: 0.3197, train_acc: 0.8904, val_acc:0.8692
# 		train_roc: 0.9504, val_roc: 0.9365, train_auprc: 0.9384, val_auprc: 0.9257
# scheduling
# Epoch: 208 (93.0217s), train_loss: 0.2736, val_loss: 0.3190, train_acc: 0.8912, val_acc:0.8702
# 		train_roc: 0.9510, val_roc: 0.9366, train_auprc: 0.9392, val_auprc: 0.9255
# scheduling
# Epoch: 209 (92.0819s), train_loss: 0.2735, val_loss: 0.3198, train_acc: 0.8912, val_acc:0.8703
# 		train_roc: 0.9512, val_roc: 0.9365, train_auprc: 0.9393, val_auprc: 0.9245
# scheduling
# Epoch: 210 (92.4637s), train_loss: 0.2758, val_loss: 0.3170, train_acc: 0.8900, val_acc:0.8708
# 		train_roc: 0.9501, val_roc: 0.9379, train_auprc: 0.9374, val_auprc: 0.9270
# scheduling
# Epoch: 211 (93.3333s), train_loss: 0.2750, val_loss: 0.3188, train_acc: 0.8900, val_acc:0.8704
# 		train_roc: 0.9504, val_roc: 0.9371, train_auprc: 0.9388, val_auprc: 0.9256
# scheduling
# Epoch: 212 (91.5727s), train_loss: 0.2739, val_loss: 0.3177, train_acc: 0.8915, val_acc:0.8712
# 		train_roc: 0.9511, val_roc: 0.9374, train_auprc: 0.9388, val_auprc: 0.9258
# scheduling
# Epoch: 213 (93.0529s), train_loss: 0.2758, val_loss: 0.3190, train_acc: 0.8905, val_acc:0.8707
# 		train_roc: 0.9501, val_roc: 0.9370, train_auprc: 0.9377, val_auprc: 0.9253
# scheduling
# Epoch: 214 (91.8258s), train_loss: 0.2746, val_loss: 0.3189, train_acc: 0.8909, val_acc:0.8701
# 		train_roc: 0.9506, val_roc: 0.9372, train_auprc: 0.9382, val_auprc: 0.9253
# scheduling
# Epoch: 215 (91.8422s), train_loss: 0.2752, val_loss: 0.3198, train_acc: 0.8902, val_acc:0.8697
# 		train_roc: 0.9506, val_roc: 0.9367, train_auprc: 0.9386, val_auprc: 0.9253
# scheduling
# Epoch: 216 (92.7160s), train_loss: 0.2745, val_loss: 0.3201, train_acc: 0.8906, val_acc:0.8698
# 		train_roc: 0.9507, val_roc: 0.9363, train_auprc: 0.9389, val_auprc: 0.9245
# scheduling
# Epoch: 217 (92.4707s), train_loss: 0.2736, val_loss: 0.3186, train_acc: 0.8911, val_acc:0.8705
# 		train_roc: 0.9511, val_roc: 0.9371, train_auprc: 0.9395, val_auprc: 0.9257
# scheduling
# Epoch: 218 (91.7632s), train_loss: 0.2746, val_loss: 0.3196, train_acc: 0.8904, val_acc:0.8696
# 		train_roc: 0.9507, val_roc: 0.9368, train_auprc: 0.9387, val_auprc: 0.9251
# scheduling
# Epoch: 219 (92.3543s), train_loss: 0.2749, val_loss: 0.3189, train_acc: 0.8905, val_acc:0.8700
# 		train_roc: 0.9504, val_roc: 0.9369, train_auprc: 0.9383, val_auprc: 0.9255
# scheduling
# Epoch: 220 (97.7274s), train_loss: 0.2738, val_loss: 0.3173, train_acc: 0.8905, val_acc:0.8702
# 		train_roc: 0.9511, val_roc: 0.9376, train_auprc: 0.9394, val_auprc: 0.9270
# scheduling
# Epoch: 221 (133.2571s), train_loss: 0.2738, val_loss: 0.3195, train_acc: 0.8912, val_acc:0.8694
# 		train_roc: 0.9509, val_roc: 0.9367, train_auprc: 0.9389, val_auprc: 0.9252
# scheduling
# Epoch: 222 (112.9809s), train_loss: 0.2744, val_loss: 0.3185, train_acc: 0.8903, val_acc:0.8704
# 		train_roc: 0.9508, val_roc: 0.9371, train_auprc: 0.9387, val_auprc: 0.9260
# scheduling
# Epoch: 223 (96.3511s), train_loss: 0.2742, val_loss: 0.3170, train_acc: 0.8908, val_acc:0.8708
# 		train_roc: 0.9510, val_roc: 0.9379, train_auprc: 0.9390, val_auprc: 0.9274
# scheduling
# Epoch: 224 (101.0193s), train_loss: 0.2756, val_loss: 0.3187, train_acc: 0.8901, val_acc:0.8709
# 		train_roc: 0.9503, val_roc: 0.9372, train_auprc: 0.9382, val_auprc: 0.9254
# scheduling
# Epoch: 225 (96.3138s), train_loss: 0.2729, val_loss: 0.3190, train_acc: 0.8914, val_acc:0.8704
# 		train_roc: 0.9515, val_roc: 0.9369, train_auprc: 0.9395, val_auprc: 0.9250
# scheduling
# Epoch: 226 (97.1907s), train_loss: 0.2747, val_loss: 0.3163, train_acc: 0.8905, val_acc:0.8717
# 		train_roc: 0.9506, val_roc: 0.9382, train_auprc: 0.9386, val_auprc: 0.9274
# scheduling
# Epoch: 227 (99.7988s), train_loss: 0.2746, val_loss: 0.3203, train_acc: 0.8906, val_acc:0.8688
# 		train_roc: 0.9506, val_roc: 0.9363, train_auprc: 0.9384, val_auprc: 0.9255
# scheduling
# Epoch: 228 (97.1488s), train_loss: 0.2750, val_loss: 0.3190, train_acc: 0.8905, val_acc:0.8699
# 		train_roc: 0.9503, val_roc: 0.9368, train_auprc: 0.9384, val_auprc: 0.9255
# scheduling
# Epoch: 229 (95.4780s), train_loss: 0.2760, val_loss: 0.3183, train_acc: 0.8897, val_acc:0.8713
# 		train_roc: 0.9503, val_roc: 0.9374, train_auprc: 0.9381, val_auprc: 0.9256
# scheduling
# Epoch: 230 (94.8502s), train_loss: 0.2738, val_loss: 0.3183, train_acc: 0.8910, val_acc:0.8703
# 		train_roc: 0.9509, val_roc: 0.9372, train_auprc: 0.9390, val_auprc: 0.9260
# scheduling
# Epoch: 231 (94.9649s), train_loss: 0.2740, val_loss: 0.3205, train_acc: 0.8906, val_acc:0.8695
# 		train_roc: 0.9510, val_roc: 0.9361, train_auprc: 0.9393, val_auprc: 0.9240
# scheduling
# Epoch: 232 (101.9244s), train_loss: 0.2732, val_loss: 0.3198, train_acc: 0.8919, val_acc:0.8697
# 		train_roc: 0.9513, val_roc: 0.9365, train_auprc: 0.9394, val_auprc: 0.9253
# scheduling
# Epoch: 233 (104.5820s), train_loss: 0.2736, val_loss: 0.3218, train_acc: 0.8909, val_acc:0.8688
# 		train_roc: 0.9512, val_roc: 0.9355, train_auprc: 0.9393, val_auprc: 0.9235
# scheduling
# Epoch: 234 (103.1599s), train_loss: 0.2748, val_loss: 0.3170, train_acc: 0.8907, val_acc:0.8714
# 		train_roc: 0.9505, val_roc: 0.9379, train_auprc: 0.9385, val_auprc: 0.9267
# scheduling
# Epoch: 235 (106.8144s), train_loss: 0.2752, val_loss: 0.3185, train_acc: 0.8905, val_acc:0.8711
# 		train_roc: 0.9503, val_roc: 0.9372, train_auprc: 0.9380, val_auprc: 0.9261
# scheduling
# Epoch: 236 (122.4855s), train_loss: 0.2741, val_loss: 0.3198, train_acc: 0.8907, val_acc:0.8694
# 		train_roc: 0.9509, val_roc: 0.9366, train_auprc: 0.9392, val_auprc: 0.9249
# scheduling
# Epoch: 237 (100.8035s), train_loss: 0.2746, val_loss: 0.3201, train_acc: 0.8907, val_acc:0.8695
# 		train_roc: 0.9508, val_roc: 0.9363, train_auprc: 0.9389, val_auprc: 0.9249
# scheduling
# Epoch: 238 (129.4894s), train_loss: 0.2738, val_loss: 0.3202, train_acc: 0.8905, val_acc:0.8709
# 		train_roc: 0.9511, val_roc: 0.9365, train_auprc: 0.9395, val_auprc: 0.9244
# scheduling
# Epoch: 239 (108.0744s), train_loss: 0.2738, val_loss: 0.3188, train_acc: 0.8912, val_acc:0.8696
# 		train_roc: 0.9508, val_roc: 0.9370, train_auprc: 0.9388, val_auprc: 0.9261
# scheduling
# Epoch: 240 (120.3124s), train_loss: 0.2752, val_loss: 0.3200, train_acc: 0.8904, val_acc:0.8697
# 		train_roc: 0.9505, val_roc: 0.9364, train_auprc: 0.9383, val_auprc: 0.9247
# scheduling
# Epoch: 241 (127.7811s), train_loss: 0.2741, val_loss: 0.3179, train_acc: 0.8908, val_acc:0.8714
# 		train_roc: 0.9509, val_roc: 0.9376, train_auprc: 0.9390, val_auprc: 0.9259
# scheduling
# Epoch: 242 (121.5815s), train_loss: 0.2726, val_loss: 0.3213, train_acc: 0.8912, val_acc:0.8693
# 		train_roc: 0.9515, val_roc: 0.9358, train_auprc: 0.9397, val_auprc: 0.9242
# scheduling
# Epoch: 243 (94.8046s), train_loss: 0.2739, val_loss: 0.3204, train_acc: 0.8911, val_acc:0.8699
# 		train_roc: 0.9510, val_roc: 0.9363, train_auprc: 0.9390, val_auprc: 0.9245
# scheduling
# Epoch: 244 (94.8279s), train_loss: 0.2738, val_loss: 0.3177, train_acc: 0.8907, val_acc:0.8706
# 		train_roc: 0.9512, val_roc: 0.9376, train_auprc: 0.9393, val_auprc: 0.9262
# scheduling
# Epoch: 245 (96.5012s), train_loss: 0.2736, val_loss: 0.3185, train_acc: 0.8914, val_acc:0.8706
# 		train_roc: 0.9512, val_roc: 0.9372, train_auprc: 0.9393, val_auprc: 0.9259
# scheduling
# Epoch: 246 (96.8800s), train_loss: 0.2747, val_loss: 0.3170, train_acc: 0.8913, val_acc:0.8717
# 		train_roc: 0.9505, val_roc: 0.9379, train_auprc: 0.9380, val_auprc: 0.9263
# scheduling
# Epoch: 247 (90.9973s), train_loss: 0.2737, val_loss: 0.3193, train_acc: 0.8913, val_acc:0.8700
# 		train_roc: 0.9512, val_roc: 0.9366, train_auprc: 0.9391, val_auprc: 0.9252
# scheduling
# Epoch: 248 (91.5451s), train_loss: 0.2739, val_loss: 0.3175, train_acc: 0.8909, val_acc:0.8713
# 		train_roc: 0.9510, val_roc: 0.9376, train_auprc: 0.9390, val_auprc: 0.9261
# scheduling
# Epoch: 249 (91.7774s), train_loss: 0.2744, val_loss: 0.3164, train_acc: 0.8906, val_acc:0.8722
# 		train_roc: 0.9508, val_roc: 0.9381, train_auprc: 0.9387, val_auprc: 0.9272
# scheduling
# Epoch: 250 (92.2562s), train_loss: 0.2752, val_loss: 0.3165, train_acc: 0.8908, val_acc:0.8721
# 		train_roc: 0.9504, val_roc: 0.9380, train_auprc: 0.9381, val_auprc: 0.9270
# scheduling
# Epoch: 251 (111.8515s), train_loss: 0.2742, val_loss: 0.3187, train_acc: 0.8908, val_acc:0.8706
# 		train_roc: 0.9510, val_roc: 0.9371, train_auprc: 0.9391, val_auprc: 0.9254
# scheduling
# Epoch: 252 (94.0011s), train_loss: 0.2727, val_loss: 0.3187, train_acc: 0.8915, val_acc:0.8709
# 		train_roc: 0.9514, val_roc: 0.9372, train_auprc: 0.9396, val_auprc: 0.9252
# scheduling
# Epoch: 253 (95.9602s), train_loss: 0.2742, val_loss: 0.3186, train_acc: 0.8909, val_acc:0.8712
# 		train_roc: 0.9508, val_roc: 0.9371, train_auprc: 0.9387, val_auprc: 0.9251
# scheduling
# Epoch: 254 (97.4051s), train_loss: 0.2739, val_loss: 0.3179, train_acc: 0.8909, val_acc:0.8702
# 		train_roc: 0.9510, val_roc: 0.9375, train_auprc: 0.9391, val_auprc: 0.9267
# scheduling
# Epoch: 255 (95.3161s), train_loss: 0.2745, val_loss: 0.3183, train_acc: 0.8906, val_acc:0.8712
# 		train_roc: 0.9508, val_roc: 0.9372, train_auprc: 0.9389, val_auprc: 0.9258
# scheduling
# Epoch: 256 (94.5162s), train_loss: 0.2741, val_loss: 0.3208, train_acc: 0.8908, val_acc:0.8705
# 		train_roc: 0.9509, val_roc: 0.9361, train_auprc: 0.9389, val_auprc: 0.9234
# scheduling
# Epoch: 257 (94.6824s), train_loss: 0.2746, val_loss: 0.3217, train_acc: 0.8905, val_acc:0.8682
# 		train_roc: 0.9507, val_roc: 0.9355, train_auprc: 0.9391, val_auprc: 0.9241
# scheduling
# Epoch: 258 (95.5728s), train_loss: 0.2740, val_loss: 0.3205, train_acc: 0.8909, val_acc:0.8685
# 		train_roc: 0.9510, val_roc: 0.9362, train_auprc: 0.9395, val_auprc: 0.9248
# scheduling
# Epoch: 259 (92.0551s), train_loss: 0.2739, val_loss: 0.3184, train_acc: 0.8906, val_acc:0.8703
# 		train_roc: 0.9510, val_roc: 0.9372, train_auprc: 0.9394, val_auprc: 0.9259
# scheduling
# Epoch: 260 (96.9173s), train_loss: 0.2742, val_loss: 0.3194, train_acc: 0.8909, val_acc:0.8696
# 		train_roc: 0.9509, val_roc: 0.9369, train_auprc: 0.9387, val_auprc: 0.9254
# scheduling
# Epoch: 261 (94.2121s), train_loss: 0.2763, val_loss: 0.3167, train_acc: 0.8895, val_acc:0.8721
# 		train_roc: 0.9502, val_roc: 0.9382, train_auprc: 0.9378, val_auprc: 0.9272
# scheduling
# Epoch: 262 (117.4751s), train_loss: 0.2743, val_loss: 0.3209, train_acc: 0.8908, val_acc:0.8691
# 		train_roc: 0.9508, val_roc: 0.9360, train_auprc: 0.9389, val_auprc: 0.9246
# scheduling
# Epoch: 263 (143.2164s), train_loss: 0.2741, val_loss: 0.3167, train_acc: 0.8904, val_acc:0.8721
# 		train_roc: 0.9509, val_roc: 0.9380, train_auprc: 0.9394, val_auprc: 0.9267
# scheduling
# Epoch: 264 (130.0981s), train_loss: 0.2746, val_loss: 0.3202, train_acc: 0.8909, val_acc:0.8695
# 		train_roc: 0.9506, val_roc: 0.9365, train_auprc: 0.9384, val_auprc: 0.9252
# scheduling
# Epoch: 265 (133.8882s), train_loss: 0.2747, val_loss: 0.3181, train_acc: 0.8906, val_acc:0.8695
# 		train_roc: 0.9506, val_roc: 0.9377, train_auprc: 0.9388, val_auprc: 0.9272
# scheduling
# Epoch: 266 (133.7429s), train_loss: 0.2738, val_loss: 0.3185, train_acc: 0.8906, val_acc:0.8708
# 		train_roc: 0.9512, val_roc: 0.9372, train_auprc: 0.9395, val_auprc: 0.9252
# scheduling
# Epoch: 267 (167.8366s), train_loss: 0.2755, val_loss: 0.3183, train_acc: 0.8905, val_acc:0.8712
# 		train_roc: 0.9502, val_roc: 0.9372, train_auprc: 0.9378, val_auprc: 0.9252
# scheduling
# Epoch: 268 (150.3673s), train_loss: 0.2749, val_loss: 0.3192, train_acc: 0.8909, val_acc:0.8699
# 		train_roc: 0.9506, val_roc: 0.9368, train_auprc: 0.9381, val_auprc: 0.9252
# scheduling
# Epoch: 269 (119.5955s), train_loss: 0.2740, val_loss: 0.3212, train_acc: 0.8907, val_acc:0.8689
# 		train_roc: 0.9510, val_roc: 0.9360, train_auprc: 0.9393, val_auprc: 0.9241
# scheduling
# Epoch: 270 (115.7553s), train_loss: 0.2748, val_loss: 0.3196, train_acc: 0.8901, val_acc:0.8685
# 		train_roc: 0.9507, val_roc: 0.9367, train_auprc: 0.9389, val_auprc: 0.9256
# scheduling
# Epoch: 271 (117.8437s), train_loss: 0.2728, val_loss: 0.3191, train_acc: 0.8914, val_acc:0.8706
# 		train_roc: 0.9513, val_roc: 0.9369, train_auprc: 0.9396, val_auprc: 0.9250
# scheduling
# Epoch: 272 (125.3157s), train_loss: 0.2753, val_loss: 0.3209, train_acc: 0.8901, val_acc:0.8692
# 		train_roc: 0.9505, val_roc: 0.9360, train_auprc: 0.9388, val_auprc: 0.9237
# scheduling
# Epoch: 273 (120.5510s), train_loss: 0.2739, val_loss: 0.3196, train_acc: 0.8911, val_acc:0.8700
# 		train_roc: 0.9509, val_roc: 0.9366, train_auprc: 0.9388, val_auprc: 0.9245
# scheduling
# Epoch: 274 (98.2811s), train_loss: 0.2741, val_loss: 0.3191, train_acc: 0.8904, val_acc:0.8713
# 		train_roc: 0.9510, val_roc: 0.9367, train_auprc: 0.9393, val_auprc: 0.9251
# scheduling
# Epoch: 275 (116.3308s), train_loss: 0.2736, val_loss: 0.3185, train_acc: 0.8911, val_acc:0.8704
# 		train_roc: 0.9512, val_roc: 0.9372, train_auprc: 0.9396, val_auprc: 0.9268
# scheduling
# Epoch: 276 (100.3280s), train_loss: 0.2749, val_loss: 0.3186, train_acc: 0.8908, val_acc:0.8710
# 		train_roc: 0.9505, val_roc: 0.9372, train_auprc: 0.9383, val_auprc: 0.9254
# scheduling
# Epoch: 277 (127.1673s), train_loss: 0.2754, val_loss: 0.3202, train_acc: 0.8903, val_acc:0.8702
# 		train_roc: 0.9505, val_roc: 0.9365, train_auprc: 0.9381, val_auprc: 0.9248
# scheduling
# Epoch: 278 (126.4872s), train_loss: 0.2752, val_loss: 0.3204, train_acc: 0.8900, val_acc:0.8695
# 		train_roc: 0.9505, val_roc: 0.9363, train_auprc: 0.9386, val_auprc: 0.9243
# scheduling
# Epoch: 279 (128.9924s), train_loss: 0.2734, val_loss: 0.3194, train_acc: 0.8912, val_acc:0.8699
# 		train_roc: 0.9511, val_roc: 0.9368, train_auprc: 0.9396, val_auprc: 0.9250
# scheduling
# Epoch: 280 (128.0687s), train_loss: 0.2748, val_loss: 0.3195, train_acc: 0.8904, val_acc:0.8701
# 		train_roc: 0.9506, val_roc: 0.9367, train_auprc: 0.9385, val_auprc: 0.9251
# scheduling
# Epoch: 281 (96.6864s), train_loss: 0.2749, val_loss: 0.3200, train_acc: 0.8900, val_acc:0.8694
# 		train_roc: 0.9507, val_roc: 0.9366, train_auprc: 0.9389, val_auprc: 0.9248
# scheduling
# Epoch: 282 (97.7596s), train_loss: 0.2749, val_loss: 0.3202, train_acc: 0.8903, val_acc:0.8700
# 		train_roc: 0.9507, val_roc: 0.9363, train_auprc: 0.9390, val_auprc: 0.9243
# scheduling
# Epoch: 283 (127.8766s), train_loss: 0.2745, val_loss: 0.3212, train_acc: 0.8905, val_acc:0.8690
# 		train_roc: 0.9509, val_roc: 0.9360, train_auprc: 0.9390, val_auprc: 0.9243
# scheduling
# Epoch: 284 (97.5386s), train_loss: 0.2751, val_loss: 0.3182, train_acc: 0.8910, val_acc:0.8719
# 		train_roc: 0.9505, val_roc: 0.9373, train_auprc: 0.9382, val_auprc: 0.9252
# scheduling
# Epoch: 285 (97.5669s), train_loss: 0.2753, val_loss: 0.3172, train_acc: 0.8911, val_acc:0.8715
# 		train_roc: 0.9505, val_roc: 0.9378, train_auprc: 0.9381, val_auprc: 0.9267
# scheduling
# Epoch: 286 (96.1946s), train_loss: 0.2741, val_loss: 0.3187, train_acc: 0.8910, val_acc:0.8711
# 		train_roc: 0.9509, val_roc: 0.9369, train_auprc: 0.9391, val_auprc: 0.9251
# scheduling
# Epoch: 287 (98.5575s), train_loss: 0.2730, val_loss: 0.3197, train_acc: 0.8917, val_acc:0.8692
# 		train_roc: 0.9514, val_roc: 0.9364, train_auprc: 0.9394, val_auprc: 0.9249
# scheduling
# Epoch: 288 (107.0036s), train_loss: 0.2739, val_loss: 0.3186, train_acc: 0.8910, val_acc:0.8713
# 		train_roc: 0.9511, val_roc: 0.9369, train_auprc: 0.9392, val_auprc: 0.9259
# scheduling
# Epoch: 289 (97.1954s), train_loss: 0.2744, val_loss: 0.3200, train_acc: 0.8909, val_acc:0.8695
# 		train_roc: 0.9507, val_roc: 0.9367, train_auprc: 0.9387, val_auprc: 0.9249
# scheduling
# Epoch: 290 (96.3164s), train_loss: 0.2750, val_loss: 0.3190, train_acc: 0.8906, val_acc:0.8700
# 		train_roc: 0.9504, val_roc: 0.9369, train_auprc: 0.9382, val_auprc: 0.9261
# scheduling
# Epoch: 291 (98.0202s), train_loss: 0.2744, val_loss: 0.3174, train_acc: 0.8907, val_acc:0.8710
# 		train_roc: 0.9507, val_roc: 0.9377, train_auprc: 0.9387, val_auprc: 0.9262
# scheduling
# Epoch: 292 (100.0029s), train_loss: 0.2753, val_loss: 0.3188, train_acc: 0.8904, val_acc:0.8707
# 		train_roc: 0.9505, val_roc: 0.9369, train_auprc: 0.9385, val_auprc: 0.9255
# scheduling
# Epoch: 293 (99.3292s), train_loss: 0.2744, val_loss: 0.3211, train_acc: 0.8909, val_acc:0.8693
# 		train_roc: 0.9508, val_roc: 0.9361, train_auprc: 0.9388, val_auprc: 0.9244
# scheduling
# Epoch: 294 (96.2668s), train_loss: 0.2750, val_loss: 0.3192, train_acc: 0.8904, val_acc:0.8699
# 		train_roc: 0.9504, val_roc: 0.9369, train_auprc: 0.9386, val_auprc: 0.9256
# scheduling
# Epoch: 295 (96.4610s), train_loss: 0.2759, val_loss: 0.3174, train_acc: 0.8903, val_acc:0.8712
# 		train_roc: 0.9501, val_roc: 0.9376, train_auprc: 0.9379, val_auprc: 0.9264
# scheduling
# Epoch: 296 (95.5725s), train_loss: 0.2733, val_loss: 0.3182, train_acc: 0.8909, val_acc:0.8701
# 		train_roc: 0.9512, val_roc: 0.9372, train_auprc: 0.9396, val_auprc: 0.9262
# scheduling
# Epoch: 297 (95.2129s), train_loss: 0.2743, val_loss: 0.3189, train_acc: 0.8909, val_acc:0.8694
# 		train_roc: 0.9508, val_roc: 0.9370, train_auprc: 0.9389, val_auprc: 0.9261
# scheduling
# Epoch: 298 (95.3083s), train_loss: 0.2748, val_loss: 0.3168, train_acc: 0.8899, val_acc:0.8711
# 		train_roc: 0.9506, val_roc: 0.9379, train_auprc: 0.9389, val_auprc: 0.9270
# scheduling
# Epoch: 299 (95.3445s), train_loss: 0.2752, val_loss: 0.3188, train_acc: 0.8900, val_acc:0.8698
# 		train_roc: 0.9505, val_roc: 0.9371, train_auprc: 0.9385, val_auprc: 0.9258
# scheduling
# Epoch: 300 (94.7242s), train_loss: 0.2749, val_loss: 0.3201, train_acc: 0.8906, val_acc:0.8703
# 		train_roc: 0.9506, val_roc: 0.9364, train_auprc: 0.9388, val_auprc: 0.9242

# %%
torch.save(model.state_dict(), 'model.pth')
